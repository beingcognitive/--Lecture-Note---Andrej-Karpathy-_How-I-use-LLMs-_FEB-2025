# %% [markdown]
# # 7. Tool use : deep research

# %% [markdown]
# 이 다음 툴로는, 최근 1~2달 사이에 발표된 기능인 Deep Research임.
#
# 러프하게 표현하자면, <b>"Search"와 "Thinking"의 결합</b>이다.
#
# 어떤 주제가 주어지면 몇분간 스스로 검색과 사고를 반복하면서 리서치를 직접 수행하는 것.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 활용 예를 들자면, Andrej는 Bryan Johnson의 Blueprint 프로젝트에서 제공하는 보조제에 대해서 궁금했다고 합니다. (* 얼마전 Netflix에서 Don't Die 라는 다큐멘터리로도 다뤄진 바가 있습니다. 본인의 신체에 여러 실험을 하는 일종의 영생 프로젝트라고 간단히 표현하고 넘어가겠습니다.)
#
# ![image.png](attachment:image.png)
#
# 그래서, (현재는 Pro, Plus사용자에서도 사용 가능한,) "Deep Research"버튼을 눌러서 질문을 시작합니다.
#
# ![image-2.png](attachment:image-2.png)
#
# 리서치 시작 전에 clarification 질문을 한번 더 나눈뒤에, 약 10분의 시간을 들여서 리서치를 진행합니다.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ==>
#
# ChatGPT의 Deep Research에 영감을 받아서, Perplexity에서도 Deep Research, Grok에서도 Deep Search와 같은 기능들을 제공하고 있지만,
#
# ChatGPT의 Deep Research가 가장 자세하면서도 가장 좋은 답변을 내놓고 있다고 생각함.

# %% [markdown]
# 이외에도, Deep Research에 물어본 질문은 다음과 같음.
#
# . 최근에 Chrome 브라우저가 모든 탭 정보를 삭제한 일이 있어서 매우 화가 났음. 그래서, 다른 브라우저들을 조사했고, 그 결과 Brave로 갈아탔다고 함. ^^;
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>. 하지만, 여전히 정말 조심해야 할 점으로는, 제아무리 Deep Research여도, 여전히 HALLUCINATION 의 가능성이 있음에 유념해야 함! </b>
#
# ![image.png](attachment:image.png)
#
# 위와 미국의 Major LLM사들에 대한 질문에 아래와 같이 Deep Research결과를 내어놓았으나,
#
# ![image-2.png](attachment:image-2.png)
#
# 우선 xAI가 빠져있고, HuggingFace는 미국회사가 아니고, EleutherAI는 Major LLM이라고 볼 수 없는 등 틀린 답변을 낸 것을 볼 수 있다.
#
# 따라서, 항상 (제아무리 Deep Research여도 Hallucination은 언제든지 알어날 수 있기 때문에) LLM의 답변은 <b>DRAFT로만 사용해야</b> 함.

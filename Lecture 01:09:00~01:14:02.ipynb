# %% [markdown]
# # 11. Claude Artifacts, apps, diagrams

# %% [markdown]
# Claude에만 있는 또다른 유용한 툴로써, Claude Artifacts라는 것을 살펴보자.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 활용 예시 통해서 바로 살펴보고자 함.
#
# (1) 아담스미스에 대한 내용을 바탕으로, 20개의 Flashcard를 만들라고 한 다음에, (wikipedia 내용에서 복붙.)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# (2) "Artifact기능을 사용해서 이 Flashcard 내용에 대해서 테스트할 수 있는 '앱'을 만들어줘"라고 요청하면,
#
# ![image.png](attachment:image.png)
#
# React라이브러리 기반으로 바로 어플리케이션을 만들었음.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 그동안은 당연히 Softward Engineer가 앱을 별도로 만들어야하는데,
#
# 이와 같이 Claude Artifacts에서 즉각적으로 커스텀 앱을 만들어준다는 것은 매우 새로운 패러다임임.
#
# 다만, Andrej가 솔직하게 말하자면, 수많은 예제들이 http://claudeartifacts.com/ 에 있으나, 본인은 이 Artifact 기능을 평소에 자주 사용하지는 않음.
#
# 그럼에도, 본인이 유용하게 사용하는 예제를 한가지 공유하자면,
#
# : 긴 글의 내용을 Conceptual Diagram으로 그려내는 경우, 해당 개념들을 보다 용이하게 이해할 수 있었다- 고 합니다.
#
# ![image.png](attachment:image.png)
#
# 참고로, 여기에 사용된 언어는 Mermaid 라이브러리이고, 이는 Graph를 효과적으로 표현한다고 합니다.
#
# 이런 활용 예시는 수많은 visual thinker들에게 책의 내용 / 코드 내용 등을 이해하기 쉽게 도와줄 것이라고 합니다. (* 저도 많이 활용해봐야겠다는 생각이 들었습니다.)
#
# ![image-2.png](attachment:image-2.png)

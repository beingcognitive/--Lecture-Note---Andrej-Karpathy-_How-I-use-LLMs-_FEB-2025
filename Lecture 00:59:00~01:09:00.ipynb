# %% [markdown]
# # 9. Tool use: python interpreter, messiness of the ecosystem

# %% [markdown]
# 30*9 같은 계산은 사람도 LLM도 암산으로 쉽게 할 수 있지만,
#
# 보다 큰 숫자가 나오면 우리는 암산 대신, 바로 계산기를 찾을 것.
#
# 마찬가지로, LLM에게도 계산기 _Python Interpreter라는 툴을 제공해서 Hallucination을 막자.
#
#
# ![image.png](attachment:image.png)
#
# 단, 아쉽게도 모든 LLM들이 이러한 계산기 툴을 사용하는 것은 아니어서, 아직은 사용자가 유의하는 수밖에 없음. 예를 들면,
#
# (1) ChatGPT-4o는 파이썬 프로그래밍을 사용하여 바로 정답을 맞췄고,
#
# ![image-4.png](attachment:image-4.png)
#
# (2) Claude 는 Javascript 툴 사용해서 정답.
#
# ![image-3.png](attachment:image-3.png)
#
# (3) 그러나, Grok 3는 툴 사용하지 않아서 매우 근접했으나 오답. (Hallucination)
#
# ![image-5.png](attachment:image-5.png)
#
# (4) Gemini 2.0 Pro Experimental은 툴을 사용하지 않았음. 단, 위 계산은 암산으로 맞추고 ^^;;
#
# ![image-6.png](attachment:image-6.png)
#
# 그래서, 다시 더 어려운 문제를 내서 툴 사용하지 않고 연산에 틀리는 것을 확인. ^^;
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 10. ChatGPT Advanced Data Analysis, figures, plots

# %% [markdown]
# ChatGPT에서 또다른 재미있는 기능으로, Advanced Data Analysis라는 것을 제공하는데,
#
# <b>이는 회사에서 Junior Data Analyst 와 협업한다고 생각하면 됨.</b>

# %% [markdown]
# 예를 들어,
#
# (1) "Search Tool을 사용해서 OpenAI의 연간 Valuation 테이블을 그려줘"라고 요청한 다음에,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (2) 이를 y축은 log스케일로 변경해서 그려줘-라고 요청하면, 아래와 같이 멋진 차트를 그려주긴 하는데,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# (3) 이를 현 추세대로 2030년값을 추정해달라고 해도, 멋진 차트를 그려주기는 하지만,
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>아직 JUNIOR data analyst 수준이라는 것을 반드시 유념해야 함.</b>
#
# 왜냐하면, (2)번 차트를 그릴 때에, 2025년에 N/A인데, 이를 임의로 아래와 같이 0.1 이라는 값을 넣어서 진행했고, (*숙련된 Data Analyst라면 요청자에게 N/A에 대한 처리를 물어봐야 함.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (3)번 차트를 그릴 때에도, 차트에서는 $20.27T를 예측하지만, 본문에서는 $1.7T라고 예측하고 있어서, 이에 대해서 아래와 같이 물어보자,
#
# "Yep, I messed up."이라고 자백하는 등...;;
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 따라서,
#
# . 멋진 차트를 그려주지만,
#
# . 아직은 JUNIOR 수준이기 때문에, 반드시 요청자가 코드를 꼼꼼히 리뷰해야하는 수준임에 유의해야 한다!
